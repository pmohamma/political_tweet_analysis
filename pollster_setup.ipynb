# %%
from rcp import get_polls, get_poll_data
from pprint import pprint
import pandas
from poll import *
from candidate import *

# %%
polls = get_polls(q="2020 Democratic")

# %%
for po in polls:
    td = get_poll_data(po['url'])
    break

# %%
pprint(td[0]['data'])
# Out:
# [{'Bennet': '0.8',
#   'Biden': '29.8',
#   'Bloomberg': '2.3',
#   'Booker': '1.3',
#   'Buttigieg': '7.8',
#   'Castro': '1.0',
#   'Date': '11/11 - 11/20',
#   'Gabbard': '2.0',
#   'Harris': '4.0',
#   'Klobuchar': '1.5',
#   'Poll': 'RCP\xa0Average',
#   'Sanders': '19.3',
#   'Spread': 'Biden +10.5',
#   'Steyer': '1.3',
#   'Warren': '18.5',
#   'Yang': '2.8'},
#  {'Bennet': '0',
#   'Biden': '27',
#   'Bloomberg': '1',
#   'Booker': '1',
#   'Buttigieg': '7',
#   'Castro': '1',
#   'Date': '11/17 - 11/20',
#   'Gabbard': '2',
#   'Harris': '3',
#   'Klobuchar': '1',
#   'Poll': 'EmersonEmerson',
#   'Sanders': '27',
#   'Spread': 'Tie',
#   'Steyer': '2',
#   'Warren': '20',
#   'Yang': '4'},
#  {'Bennet': '1',
#   'Biden': '30',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '9',
#   'Castro': '0',
#   'Date': '11/17 - 11/19',
#   'Gabbard': '3',
#   'Harris': '4',
#   'Klobuchar': '2',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '12',
#   'Spread': 'Biden +8',
#   'Steyer': '1',
#   'Warren': '22',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '30',
#   'Bloomberg': '3',
#   'Booker': '1',
#   'Buttigieg': '7',
#   'Castro': '2',
#   'Date': '11/16 - 11/17',
#   'Gabbard': '1',
#   'Harris': '4',
#   'Klobuchar': '1',
#   'Poll': 'The Hill/HarrisXThe Hill',
#   'Sanders': '18',
#   'Spread': 'Biden +12',
#   'Steyer': '1',
#   'Warren': '15',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '32',
#   'Bloomberg': '3',
#   'Booker': '2',
#   'Buttigieg': '8',
#   'Castro': '1',
#   'Date': '11/11 - 11/17',
#   'Gabbard': '2',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '20',
#   'Spread': 'Biden +12',
#   'Steyer': '1',
#   'Warren': '17',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '23',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '9',
#   'Castro': '2',
#   'Date': '11/10 - 11/12',
#   'Gabbard': '2',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '17',
#   'Spread': 'Warren +3',
#   'Steyer': '1',
#   'Warren': '26',
#   'Yang': '4'},
#  {'Bennet': '1',
#   'Biden': '32',
#   'Bloomberg': '2',
#   'Booker': '3',
#   'Buttigieg': '8',
#   'Castro': '1',
#   'Date': '11/4 - 11/10',
#   'Gabbard': '1',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '20',
#   'Spread': 'Biden +12',
#   'Steyer': '1',
#   'Warren': '19',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '26',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '8',
#   'Castro': '3',
#   'Date': '11/3 - 11/5',
#   'Gabbard': '3',
#   'Harris': '6',
#   'Klobuchar': '2',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '14',
#   'Spread': 'Biden +1',
#   'Steyer': '1',
#   'Warren': '25',
#   'Yang': '1'},
#  {'Bennet': '0',
#   'Biden': '23',
#   'Bloomberg': '--',
#   'Booker': '3',
#   'Buttigieg': '9',
#   'Castro': '0',
#   'Date': '10/30 - 11/3',
#   'Gabbard': '0',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'MonmouthMonmouth',
#   'Sanders': '20',
#   'Spread': 'Tie',
#   'Steyer': '1',
#   'Warren': '23',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '26',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '6',
#   'Castro': '2',
#   'Date': '11/1 - 11/2',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '3',
#   'Poll': 'The Hill/HarrisXThe Hill',
#   'Sanders': '14',
#   'Spread': 'Biden +11',
#   'Steyer': '1',
#   'Warren': '15',
#   'Yang': '1'},
#  {'Bennet': '1',
#   'Biden': '32',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '7',
#   'Castro': '1',
#   'Date': '10/28 - 11/3',
#   'Gabbard': '2',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '20',
#   'Spread': 'Biden +12',
#   'Steyer': '1',
#   'Warren': '20',
#   'Yang': '3'},
#  {'Bennet': '--',
#   'Biden': '33',
#   'Bloomberg': '--',
#   'Booker': '3',
#   'Buttigieg': '4',
#   'Castro': '0',
#   'Date': '10/29 - 10/31',
#   'Gabbard': '0',
#   'Harris': '5',
#   'Klobuchar': '3',
#   'Poll': 'Harvard-HarrisHarris',
#   'Sanders': '18',
#   'Spread': 'Biden +15',
#   'Steyer': '1',
#   'Warren': '15',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '27',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '6',
#   'Castro': '1',
#   'Date': '10/27 - 10/30',
#   'Gabbard': '2',
#   'Harris': '4',
#   'Klobuchar': '5',
#   'Poll': 'NBC News/Wall St. JrnlNBC/WSJ',
#   'Sanders': '19',
#   'Spread': 'Biden +4',
#   'Steyer': '0',
#   'Warren': '23',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '28',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '9',
#   'Castro': '1',
#   'Date': '10/27 - 10/30',
#   'Gabbard': '2',
#   'Harris': '2',
#   'Klobuchar': '2',
#   'Poll': 'ABC News/Wash PostABC/WP',
#   'Sanders': '17',
#   'Spread': 'Biden +5',
#   'Steyer': '1',
#   'Warren': '23',
#   'Yang': '2'},
#  {'Bennet': '0',
#   'Biden': '31',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '7',
#   'Castro': '0',
#   'Date': '10/27 - 10/30',
#   'Gabbard': '2',
#   'Harris': '3',
#   'Klobuchar': '2',
#   'Poll': 'FOX NewsFOX News',
#   'Sanders': '19',
#   'Spread': 'Biden +10',
#   'Steyer': '1',
#   'Warren': '21',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '27',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '7',
#   'Castro': '1',
#   'Date': '10/27 - 10/29',
#   'Gabbard': '2',
#   'Harris': '4',
#   'Klobuchar': '2',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '14',
#   'Spread': 'Biden +4',
#   'Steyer': '1',
#   'Warren': '23',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '28',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '6',
#   'Castro': '0',
#   'Date': '10/21 - 11/3',
#   'Gabbard': '1',
#   'Harris': '4',
#   'Klobuchar': '2',
#   'Poll': 'LA Times/USCLA Times',
#   'Sanders': '13',
#   'Spread': 'Biden +12',
#   'Steyer': '1',
#   'Warren': '16',
#   'Yang': '2'},
#  {'Bennet': '0',
#   'Biden': '29',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '7',
#   'Castro': '1',
#   'Date': '10/24 - 10/31',
#   'Gabbard': '0',
#   'Harris': '2',
#   'Klobuchar': '3',
#   'Poll': 'IBD/TIPPIBD/TIPP',
#   'Sanders': '13',
#   'Spread': 'Biden +6',
#   'Steyer': '1',
#   'Warren': '23',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '26',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '10',
#   'Castro': '0',
#   'Date': '10/23 - 10/26',
#   'Gabbard': '4',
#   'Harris': '3',
#   'Klobuchar': '2',
#   'Poll': 'USA Today/SuffolkUSA Today',
#   'Sanders': '13',
#   'Spread': 'Biden +9',
#   'Steyer': '1',
#   'Warren': '17',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '32',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '7',
#   'Castro': '1',
#   'Date': '10/21 - 10/27',
#   'Gabbard': '2',
#   'Harris': '6',
#   'Klobuchar': '2',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '20',
#   'Spread': 'Biden +12',
#   'Steyer': '1',
#   'Warren': '20',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '27',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '6',
#   'Castro': '1',
#   'Date': '10/21 - 10/22',
#   'Gabbard': '0',
#   'Harris': '5',
#   'Klobuchar': '1',
#   'Poll': 'The Hill/HarrisXThe Hill',
#   'Sanders': '14',
#   'Spread': 'Biden +8',
#   'Steyer': '1',
#   'Warren': '19',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '24',
#   'Bloomberg': '--',
#   'Booker': '3',
#   'Buttigieg': '8',
#   'Castro': '1',
#   'Date': '10/20 - 10/22',
#   'Gabbard': '2',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '16',
#   'Spread': 'Biden +1',
#   'Steyer': '1',
#   'Warren': '23',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '27',
#   'Bloomberg': '--',
#   'Booker': '3',
#   'Buttigieg': '6',
#   'Castro': '0',
#   'Date': '10/18 - 10/21',
#   'Gabbard': '3',
#   'Harris': '5',
#   'Klobuchar': '1',
#   'Poll': 'EmersonEmerson',
#   'Sanders': '25',
#   'Spread': 'Biden +2',
#   'Steyer': '1',
#   'Warren': '21',
#   'Yang': '4'},
#  {'Bennet': '0',
#   'Biden': '21',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '10',
#   'Castro': '1',
#   'Date': '10/17 - 10/21',
#   'Gabbard': '1',
#   'Harris': '5',
#   'Klobuchar': '3',
#   'Poll': 'QuinnipiacQuinnipiac',
#   'Sanders': '15',
#   'Spread': 'Warren +7',
#   'Steyer': '1',
#   'Warren': '28',
#   'Yang': '1'},
#  {'Bennet': '1',
#   'Biden': '34',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '6',
#   'Castro': '0',
#   'Date': '10/17 - 10/20',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '3',
#   'Poll': 'CNNCNN',
#   'Sanders': '16',
#   'Spread': 'Biden +15',
#   'Steyer': '1',
#   'Warren': '19',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '30',
#   'Bloomberg': '--',
#   'Booker': '3',
#   'Buttigieg': '6',
#   'Castro': '1',
#   'Date': '10/16 - 10/20',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '2',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '18',
#   'Spread': 'Biden +9',
#   'Steyer': '1',
#   'Warren': '21',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '31',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '6',
#   'Castro': '1',
#   'Date': '10/16 - 10/16',
#   'Gabbard': '1',
#   'Harris': '7',
#   'Klobuchar': '2',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '18',
#   'Spread': 'Biden +10',
#   'Steyer': '2',
#   'Warren': '21',
#   'Yang': '3'},
#  {'Bennet': '--',
#   'Biden': '32',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '5',
#   'Castro': '1',
#   'Date': '10/15 - 10/16',
#   'Gabbard': '1',
#   'Harris': '7',
#   'Klobuchar': '2',
#   'Poll': 'SurveyUSASUSA',
#   'Sanders': '17',
#   'Spread': 'Biden +10',
#   'Steyer': '1',
#   'Warren': '22',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '25',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '7',
#   'Castro': '0',
#   'Date': '10/13 - 10/15',
#   'Gabbard': '3',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '13',
#   'Spread': 'Warren +4',
#   'Steyer': '1',
#   'Warren': '29',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '27',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '8',
#   'Castro': '1',
#   'Date': '10/11 - 10/13',
#   'Gabbard': '0',
#   'Harris': '4',
#   'Klobuchar': '2',
#   'Poll': 'QuinnipiacQuinnipiac',
#   'Sanders': '11',
#   'Spread': 'Warren +3',
#   'Steyer': '2',
#   'Warren': '30',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '32',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '5',
#   'Castro': '1',
#   'Date': '10/7 - 10/12',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '1',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '19',
#   'Spread': 'Biden +11',
#   'Steyer': '1',
#   'Warren': '21',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '25',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '5',
#   'Castro': '1',
#   'Date': '10/6 - 10/8',
#   'Gabbard': '1',
#   'Harris': '5',
#   'Klobuchar': '1',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '14',
#   'Spread': 'Warren +4',
#   'Steyer': '1',
#   'Warren': '29',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '32',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '4',
#   'Castro': '1',
#   'Date': '10/6 - 10/8',
#   'Gabbard': '1',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'FOX NewsFOX News',
#   'Sanders': '17',
#   'Spread': 'Biden +10',
#   'Steyer': '1',
#   'Warren': '22',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '31',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '4',
#   'Castro': '1',
#   'Date': '10/6 - 10/7',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '2',
#   'Poll': 'The Hill/HarrisXThe Hill',
#   'Sanders': '17',
#   'Spread': 'Biden +14',
#   'Steyer': '2',
#   'Warren': '15',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '26',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '4',
#   'Castro': '1',
#   'Date': '10/4 - 10/7',
#   'Gabbard': '0',
#   'Harris': '3',
#   'Klobuchar': '2',
#   'Poll': 'QuinnipiacQuinnipiac',
#   'Sanders': '16',
#   'Spread': 'Warren +3',
#   'Steyer': '0',
#   'Warren': '29',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '33',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '5',
#   'Castro': '1',
#   'Date': '9/30 - 10/6',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '1',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '19',
#   'Spread': 'Biden +12',
#   'Steyer': '1',
#   'Warren': '21',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '26',
#   'Bloomberg': '--',
#   'Booker': '0',
#   'Buttigieg': '7',
#   'Castro': '1',
#   'Date': '9/26 - 10/3',
#   'Gabbard': '1',
#   'Harris': '3',
#   'Klobuchar': '1',
#   'Poll': 'IBD/TIPPIBD/TIPP',
#   'Sanders': '10',
#   'Spread': 'Warren +1',
#   'Steyer': '0',
#   'Warren': '27',
#   'Yang': '3'},
#  {'Bennet': '2',
#   'Biden': '22',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '7',
#   'Castro': '1',
#   'Date': '9/28 - 10/1',
#   'Gabbard': '2',
#   'Harris': '5',
#   'Klobuchar': '1',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '13',
#   'Spread': 'Warren +6',
#   'Steyer': '1',
#   'Warren': '28',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '25',
#   'Bloomberg': '--',
#   'Booker': '1',
#   'Buttigieg': '5',
#   'Castro': '1',
#   'Date': '9/23 - 9/29',
#   'Gabbard': '0',
#   'Harris': '5',
#   'Klobuchar': '1',
#   'Poll': 'MonmouthMonmouth',
#   'Sanders': '15',
#   'Spread': 'Warren +3',
#   'Steyer': '1',
#   'Warren': '28',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '32',
#   'Bloomberg': '--',
#   'Booker': '3',
#   'Buttigieg': '5',
#   'Castro': '1',
#   'Date': '9/23 - 9/29',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '1',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '19',
#   'Spread': 'Biden +11',
#   'Steyer': '1',
#   'Warren': '21',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '26',
#   'Bloomberg': '--',
#   'Booker': '0',
#   'Buttigieg': '6',
#   'Castro': '0',
#   'Date': '9/22 - 9/24',
#   'Gabbard': '1',
#   'Harris': '4',
#   'Klobuchar': '1',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '16',
#   'Spread': 'Warren +1',
#   'Steyer': '0',
#   'Warren': '27',
#   'Yang': '2'},
#  {'Bennet': '--',
#   'Biden': '28',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '3',
#   'Castro': '2',
#   'Date': '9/22 - 9/24',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '1',
#   'Poll': 'Harvard-HarrisHarris',
#   'Sanders': '16',
#   'Spread': 'Biden +11',
#   'Steyer': '2',
#   'Warren': '17',
#   'Yang': '3'},
#  {'Bennet': '0',
#   'Biden': '25',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '6',
#   'Castro': '2',
#   'Date': '9/21 - 9/23',
#   'Gabbard': '1',
#   'Harris': '4',
#   'Klobuchar': '0',
#   'Poll': 'EmersonEmerson',
#   'Sanders': '22',
#   'Spread': 'Biden +2',
#   'Steyer': '0',
#   'Warren': '23',
#   'Yang': '8'},
#  {'Bennet': '1',
#   'Biden': '25',
#   'Bloomberg': '--',
#   'Booker': '0',
#   'Buttigieg': '7',
#   'Castro': '2',
#   'Date': '9/19 - 9/23',
#   'Gabbard': '1',
#   'Harris': '3',
#   'Klobuchar': '2',
#   'Poll': 'QuinnipiacQuinnipiac',
#   'Sanders': '16',
#   'Spread': 'Warren +2',
#   'Steyer': '0',
#   'Warren': '27',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '31',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '5',
#   'Castro': '3',
#   'Date': '9/20 - 9/21',
#   'Gabbard': '1',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'The Hill/HarrisXThe Hill',
#   'Sanders': '16',
#   'Spread': 'Biden +15',
#   'Steyer': '1',
#   'Warren': '14',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '32',
#   'Bloomberg': '--',
#   'Booker': '3',
#   'Buttigieg': '5',
#   'Castro': '1',
#   'Date': '9/16 - 9/22',
#   'Gabbard': '1',
#   'Harris': '6',
#   'Klobuchar': '2',
#   'Poll': 'Politico/Morning ConsultPolitico',
#   'Sanders': '19',
#   'Spread': 'Biden +12',
#   'Steyer': '1',
#   'Warren': '20',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '29',
#   'Bloomberg': '--',
#   'Booker': '3',
#   'Buttigieg': '5',
#   'Castro': '0',
#   'Date': '9/15 - 9/17',
#   'Gabbard': '0',
#   'Harris': '7',
#   'Klobuchar': '2',
#   'Poll': 'FOX NewsFOX News',
#   'Sanders': '18',
#   'Spread': 'Biden +11',
#   'Steyer': '1',
#   'Warren': '16',
#   'Yang': '2'},
#  {'Bennet': '1',
#   'Biden': '26',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '9',
#   'Castro': '1',
#   'Date': '9/14 - 9/17',
#   'Gabbard': '2',
#   'Harris': '6',
#   'Klobuchar': '1',
#   'Poll': 'Economist/YouGovEconomist',
#   'Sanders': '14',
#   'Spread': 'Biden +5',
#   'Steyer': '0',
#   'Warren': '21',
#   'Yang': '3'},
#  {'Bennet': '1',
#   'Biden': '31',
#   'Bloomberg': '--',
#   'Booker': '2',
#   'Buttigieg': '7',
#   'Castro': '1',
#   'Date': '9/13 - 9/16',
#   'Gabbard': '1',
#   'Harris': '5',
#   'Klobuchar': '2',
#   'Poll': 'NBC News/Wall St. JrnlNBC/WSJ',
#   'Sanders': '14',
#   'Spread': 'Biden +6',
#   'Steyer': '1',
#   'Warren': '25',
#   'Yang': '4'}]

# %%
polls = [None]*len(td[0]['data'])
for i in range(len(td[0]['data'])):
    polls[i] = Poll(td[0]['data'][i])
    
candidate_set = set()
for p in polls:
    print(p.get_sorted_results())
    p.update_candidates(candidate_set)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b6aa1a27d77d> in <module>
#       1 polls = [None]*len(td[0]['data'])
#       2 for i in range(len(td[0]['data'])):
# ----> 3     polls[i] = Poll(td[0]['data'][i])
#       4
#       5 candidate_set = set()
#
# ~\Anaconda3\projects\candidate_tweet_analysis\poll.py in __init__(self, poll)
#      15
#      16                 #returns tuple of (percentage, candidate name), sorted by a candidate's position in the polls, 1st to last
# ---> 17                 self.sorted_results = self.sort_results(poll)
#      18
#      19
#
# ~\Anaconda3\projects\candidate_tweet_analysis\poll.py in sort_results(self, poll)
#      42                 for person in poll:
#      43                         if person != "Poll" and person != "Date" and person != "Spread":
# ---> 44                                 results.append((float(poll[person]), person))
#      45                 results.sort(key = lambda x:x[0])
#      46                 return results
#
# ValueError: could not convert string to float: '--'

# %%
for i in candidate_set:
    print(i)
    for j in (i.polls):
        print(j)
    print("\n\n")
